# %%
# For example, here's several helpful packages to load

import pandas as pd
data=pd.read_csv('/kaggle/input/gitignore/custom_phishing_dataset.csv')
print(data.head())
print("Row and column:",data.shape)
print("Missing values:\n",data.isnull().sum())
print("Target distribution:\n",data['Is_Phishing'].value_counts())

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
#                                      URL  Have_IP  Have_At_Symbol  URL_Length  \
# 0               http://192.168.1.1/login        1               0          24
# 1                 https://www.google.com        0               0          22
# 2  http://phishingsite.com@malicious.com        0               1          38
# 3      http://example.com/update-account        0               0          33
# 4              https://secure.paypal.com        0               0          26
#
#    Is_Https  Is_Phishing
# 0         0            1
# 1         1            0
# 2         0            1
# 3         0            1
# 4         1            0
# Row and column: (10, 6)
# Missing values:
#  URL               0
# Have_IP           0
# Have_At_Symbol    0
# URL_Length        0
# Is_Https          0
# Is_Phishing       0
# dtype: int64
# Target distribution:
#  Is_Phishing
# 1    6
# 0    4
# Name: count, dtype: int64

# %%
data.dropna(inplace=True)
X = data[['Have_IP','Have_At_Symbol', 'URL_Length','Is_Https']]
Y = data['Is_Phishing']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticsRegression
from sklearn matrics import accuracy_score

X_train X_test Y_train Y_test = train_test_split(random)
model = LogisticsRegression()
model = fat(X_train Y_train)
# Out:
#   File "/tmp/ipykernel_36/296693043.py", line 3
#     from sklearn matrix import accuracy_score
#                  ^
# SyntaxError: invalid syntax
